# %% [markdown]
# # Superstore Analytics Project
#
# ## Pandas και Matplotlib
#
# Το Superstore θέλει να κατανοήσει ποιες κατηγορίες, περιοχές και προϊόντα
# φέρνουν τις περισσότερες πωλήσεις και ποια συνδέονται με ζημιές.
#
# Στο project θα:
#
# 1. καθαρίσεις ένα dataset με λίγα προβλήματα ποιότητας,
# 2. εξερευνήσεις πωλήσεις, κέρδος, πελάτες και παραγγελίες,
# 3. απαντήσεις σε business ερωτήματα με Pandas,
# 4. δημιουργήσεις διαγράμματα με Matplotlib.
#
# Θα χρησιμοποιήσεις μόνο τεχνικές από τα μαθήματα:
#
# - `read_csv`, `head`, `info`, `describe`, `shape`
# - επιλογή στηλών και Boolean filtering
# - `rename`, `drop_duplicates`, `fillna`, `replace`, `astype`
# - `value_counts`, `groupby`, `pd.cut`, `pd.to_datetime`
# - `plt.bar`, `plt.barh`, `plt.hist` και `plt.plot`
#
# **Το μοναδικό αρχείο δεδομένων που χρειάζεται είναι:**
# `superstore_project_unclean.csv`

# %% [markdown]
# ## Χρήσιμες στήλες
#
# - `Order ID`: μοναδικός κωδικός παραγγελίας
# - `Order Date`, `Ship Date`: ημερομηνία παραγγελίας και αποστολής
# - `Customer ID`, `Segment`: πελάτης και κατηγορία πελάτη
# - `Region`, `State`, `City`: γεωγραφικά στοιχεία
# - `Category`, `Sub-Category`: κατηγορία και υποκατηγορία προϊόντος
# - `Sales`: αξία πώλησης
# - `Quantity`: ποσότητα
# - `Discount`: έκπτωση από 0 έως 0.8
# - `Profit`: κέρδος ή ζημιά
#
# Κάθε γραμμή αντιστοιχεί σε μία γραμμή προϊόντος μιας παραγγελίας. Για αυτό,
# όταν μετράμε παραγγελίες χρησιμοποιούμε το `nunique()` του `Order ID`.

# %% [markdown]
# ## 0. Προετοιμασία
#
# Το notebook και το CSV πρέπει να βρίσκονται στον ίδιο φάκελο.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Μέρος A — Φόρτωση και αρχικός έλεγχος

# %% [markdown]
# ### 1. Φόρτωση του dataset
#
#
# Διάβασε το `superstore_project_unclean.csv` σε DataFrame με όνομα `df`.
# Εμφάνισε τις πρώτες πέντε γραμμές και το `shape`.

# %%
# TODO: διάβασε το CSV
# TODO: εμφάνισε head() και shape

# %% [markdown]
# ### 2. Πρώτος έλεγχος των δεδομένων
#
#
# Χρησιμοποίησε:
#
# - `info()` για τις στήλες και τους τύπους,
# - `isna().sum()` για τις κενές τιμές,
# - `duplicated().sum()` για τα διπλότυπα,
# - `value_counts()` για `Category`, `Region` και `Ship Mode`.

# %%
# TODO: info()
# TODO: κενές τιμές
# TODO: πλήθος διπλότυπων
# TODO: value_counts() στις τρεις κατηγορικές στήλες

# %% [markdown]
# ## Μέρος B — Καθαρισμός δεδομένων

# %% [markdown]
# ### 3. Διόρθωση ονομάτων στηλών
#
#
# Μετονόμασε:
#
# - `Order_ID` σε `Order ID`
# - `Sub Category` σε `Sub-Category`

# %%
# TODO: χρησιμοποίησε rename(columns={...})

# %% [markdown]
# ### 4. Αφαίρεση διπλότυπων
#
#
# Αφαίρεσε τις πλήρως διπλότυπες γραμμές με `drop_duplicates()` και αποθήκευσε
# ξανά το αποτέλεσμα στο `df`.

# %%
# TODO: αφαίρεσε τα duplicates

# %% [markdown]
# ### 5. Καθαρισμός κατηγορικών τιμών
#
#
# Καθάρισε τις `Category`, `Region` και `Ship Mode` με `strip()` και `title()`.
# Στη συνέχεια έλεγξε ξανά τις τιμές τους με `value_counts()`.

# %%
# TODO: strip() και title() στις τρεις στήλες
# TODO: value_counts() μετά τον καθαρισμό

# %% [markdown]
# ### 6. Εντοπισμός μη έγκυρων ποσοτήτων
#
#
# Στο αρχικό dataset η `Quantity` βρίσκεται από 1 έως 14. Δημιούργησε Boolean
# mask για ποσότητες μικρότερες από 1 ή μεγαλύτερες από 14 και αντικατάστησέ
# τες με `NaN`.

# %%
# TODO: δημιούργησε το invalid_quantities
# TODO: εμφάνισε τις προβληματικές τιμές
# TODO: αντικατάστησέ τες με NaN χρησιμοποιώντας loc

# %% [markdown]
# ### 7. Συμπλήρωση κενών τιμών
#
#
# Συμπλήρωσε:
#
# - `Sales`, `Profit` και `Quantity` με τη διάμεσό τους,
# - `Category` με την επικρατούσα τιμή.
#
# Στρογγυλοποίησε τη διάμεσο της `Quantity` και μετέτρεψε τη στήλη σε `int`.
# Οι `Sales` και `Profit` πρέπει να παραμείνουν δεκαδικές.

# %%
# TODO: median και fillna για Sales και Profit
# TODO: median, round, fillna και astype(int) για Quantity
# TODO: mode και fillna για Category

# %% [markdown]
# ### 8. Μετατροπή ημερομηνιών
#
#
# Μετέτρεψε τις `Order Date` και `Ship Date` σε datetime με `pd.to_datetime()`.
# Εμφάνισε τους νέους τύπους δεδομένων.

# %%
# TODO: pd.to_datetime() στις δύο στήλες
# TODO: εμφάνισε τα dtypes

# %% [markdown]
# ### 9. Στήλη χωρίς πληροφορία και τελικός έλεγχος
#
#
# Η `Country` έχει την ίδια τιμή σε όλες τις γραμμές. Επιβεβαίωσέ το με
# `nunique()` και αφαίρεσε τη στήλη.
#
# Στη συνέχεια εμφάνισε το τελικό shape, τις συνολικές κενές τιμές, τα
# διπλότυπα και το ελάχιστο/μέγιστο `Quantity`.

# %%
# TODO: έλεγξε το nunique() του Country
# TODO: αφαίρεσε το Country
# TODO: τελικοί έλεγχοι με print

# %% [markdown]
# ## Μέρος C — Βασική διερεύνηση
#
# Σε κάθε άσκηση υπολόγισε πρώτα το αποτέλεσμα με Pandas και μετά δημιούργησε
# το κατάλληλο διάγραμμα με Matplotlib.

# %% [markdown]
# ### 10. Βασικά μεγέθη του Superstore
#
#
# Υπολόγισε:
#
# - το πλήθος μοναδικών παραγγελιών,
# - το πλήθος μοναδικών πελατών,
# - τις συνολικές πωλήσεις,
# - το συνολικό κέρδος,
# - το συνολικό περιθώριο κέρδους:
#   `total_profit / total_sales * 100`.

# %%
# TODO: orders και customers με nunique()
# TODO: total_sales και total_profit με sum()
# TODO: profit_margin

# %% [markdown]
# ### 11. Συνολικές πωλήσεις ανά Category
#
#
# Υπολόγισε τις συνολικές `Sales` ανά `Category`, ταξινόμησε το αποτέλεσμα και
# δημιούργησε bar chart με `plt.bar()`.

# %%
# TODO: groupby Category και sum()
# TODO: sort_values()
# TODO: plt.bar(), title, xlabel, ylabel και show

# %% [markdown]
# ### 12. Συνολικό κέρδος ανά Region
#
#
# Υπολόγισε το συνολικό `Profit` ανά `Region`, ταξινόμησε το αποτέλεσμα και
# δημιούργησε bar chart με `plt.bar()`.

# %%
# TODO: groupby Region και sum()
# TODO: sort_values()
# TODO: plt.bar(), title, xlabel, ylabel και show

# %% [markdown]
# ### 13. Κατανομή των Sales
#
#
# Εμφάνισε το `describe()` της `Sales` και δημιούργησε histogram με
# `plt.hist()`. Επειδή υπάρχουν λίγες πολύ μεγάλες πωλήσεις, χρησιμοποίησε μόνο
# τις γραμμές με `Sales <= 1000` για πιο ευανάγνωστο διάγραμμα.

# %%
# TODO: describe()
# TODO: φίλτραρε Sales <= 1000
# TODO: plt.hist() με 20 bins
# TODO: title, xlabel, ylabel και show

# %% [markdown]
# ### 14. Μέση πώληση ανά Segment
#
#
# Υπολόγισε τη μέση `Sales` ανά `Segment`, ταξινόμησε το αποτέλεσμα και
# δημιούργησε bar chart.

# %%
# TODO: groupby Segment και mean()
# TODO: sort_values()
# TODO: plt.bar()

# %% [markdown]
# ### 15. Πλήθος παραγγελιών ανά Ship Mode
#
#
# Υπολόγισε το πλήθος **μοναδικών παραγγελιών** ανά `Ship Mode` με
# `groupby()` και `nunique()`. Ταξινόμησε και δημιούργησε horizontal bar chart.

# %%
# TODO: groupby Ship Mode και nunique() του Order ID
# TODO: sort_values()
# TODO: plt.barh()

# %% [markdown]
# ## Μέρος D — Συνδυαστικές ασκήσεις
#
# Οι επόμενες ασκήσεις χρειάζονται 2-3 απλά βήματα Pandas πριν από την
# οπτικοποίηση. Αποθήκευσε τα ενδιάμεσα αποτελέσματα σε ξεχωριστές μεταβλητές.

# %% [markdown]
# ### 16. Sales και Profit ανά Category
#
#
# 1. Υπολόγισε τις συνολικές `Sales` ανά `Category`.
# 2. Υπολόγισε το συνολικό `Profit` ανά `Category`.
# 3. Βάλε τα δύο Series σε DataFrame με όνομα `category_summary`.
# 4. Δημιούργησε δύο διαγράμματα δίπλα-δίπλα με `plt.subplot()`:
#    ένα για τις πωλήσεις και ένα για το κέρδος.

# %%
# TODO: δημιούργησε τα sales_by_category και profit_by_category
# TODO: δημιούργησε το category_summary DataFrame
# TODO: πρώτο subplot με Sales
# TODO: δεύτερο subplot με Profit
# TODO: tight_layout() και show()

# %% [markdown]
# ### 17. Ετήσια εξέλιξη Sales και Profit
#
#
# 1. Δημιούργησε στήλη `Order Year` από το έτος της `Order Date`.
# 2. Υπολόγισε συνολικά `Sales` και `Profit` ανά έτος.
# 3. Δημιούργησε δύο γραμμές στο ίδιο διάγραμμα με `plt.plot()` και πρόσθεσε
#    legend.

# %%
# TODO: Order Year με dt.year
# TODO: δύο groupby() και sum()
# TODO: δύο plt.plot() με marker και label
# TODO: title, xlabel, ylabel, legend και show

# %% [markdown]
# ### 18. Υποκατηγορίες με το χαμηλότερο Profit
#
#
# 1. Υπολόγισε το συνολικό `Profit` ανά `Sub-Category`.
# 2. Ταξινόμησε σε αύξουσα σειρά.
# 3. Κράτησε τις πρώτες 7 υποκατηγορίες.
# 4. Δημιούργησε horizontal bar chart.
#
# **Ερώτημα:** Ποιες υποκατηγορίες προκαλούν ζημιές;

# %%
# TODO: groupby Sub-Category και sum()
# TODO: sort_values() και head(7)
# TODO: plt.barh()

# %% [markdown]
# ### 19. Discount Group και συνολικό Profit
#
#
# 1. Δημιούργησε `Discount Group` με `pd.cut()` και τις ομάδες:
#    `0%`, `1%-20%`, `21%-40%`, `41%-60%`, `61%-80%`.
# 2. Μετέτρεψε τη νέα στήλη σε string.
# 3. Υπολόγισε το συνολικό `Profit` ανά ομάδα έκπτωσης.
# 4. Δημιούργησε bar chart.
#
# **Ερώτημα:** Από ποιο επίπεδο έκπτωσης και μετά εμφανίζονται συνολικές ζημιές;

# %%
# TODO: bins και labels
# TODO: pd.cut() και astype(str)
# TODO: groupby Discount Group και sum()
# TODO: plt.bar()

# %% [markdown]
# ## Μέρος E — Συμπεράσματα
#
# Γράψε 5-7 προτάσεις:
#
# 1. Ποια κατηγορία έχει τις περισσότερες πωλήσεις;
# 2. Ποια περιοχή έχει το μεγαλύτερο συνολικό κέρδος;
# 3. Πώς εξελίσσονται οι πωλήσεις και το κέρδος ανά έτος;
# 4. Ποιες υποκατηγορίες προκαλούν ζημιές;
# 5. Πώς συνδέεται το ύψος της έκπτωσης με το συνολικό κέρδος;
# 6. Ποιες κατηγορίες ή υποκατηγορίες χρειάζονται περαιτέρω διερεύνηση;
#
# ### Η απάντησή σου
#
# _Γράψε εδώ τα συμπεράσματά σου._

# %% [markdown]
# ## Προαιρετικό — Αποθήκευση του καθαρού dataset
#
# ```python
# # df.to_csv("superstore_project_cleaned.csv", index=False)
# ```
